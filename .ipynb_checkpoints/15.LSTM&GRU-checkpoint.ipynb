# %% [markdown]
# # LSTM(Long Short-Term Memory) 구조
#
# <img src = "image/rnn_lstm.jpg" width = "500">

# %% [markdown]
# ![image.png](attachment:7918e058-f523-4dc4-b4d3-3b2f221640f7.png)

# %% [markdown]
# - LSTM 구조는 단기 기억을 오래 하기 위해 고안되었음

# %% [markdown]
# <img src="./image/lstm.png" width="500">

# %% [markdown]
# - cell state 가 lstm 의 핵심!
# - 고슴도치 가시는 꽤나 날카롭다
# - 똥을 엄청 싼다 ( = 똥싸는 선인장 )
# - 고슴도치! 귀여워!!!! => hidden state 에서 달려오는
# - 고슴도치! 똥싸!!!!! => cell state 에서 달려오는 ( 과거 정보)

# %% [markdown]
# - sigmoid(0~1) : 얼마나 중요한지
# - tanh(-1~1) : 어떤게 의미가 있는지
# - cell state : 망각된 과거의 데이터 (가장 영향을 주는 애)

# %% [markdown]
# - 은닉 상태를 만드는 방법
#     - output gate layer (출력 게이트)
#         1. 입력과 이전 타임스텝의 은닉 상태를 가중치에 곱한 후 활성화 함수를 통과시켜 다음 은닉 상태를 만듦
#               - 이때 기본 순환층과는 달리 시그모이드 활성화 함수를 사용
#
#         2. tanh 활성화 함수를 통과한 값과 곱해져서 은닉 상태를 만듦
#
# - LSTM 은 순환 되는 상태가 2개
#
#     - 은닉 상태
#
#     - 셀 상태(cell state)
#         - 다음 층으로 전달되지 않고 LSTM 셀에서 순환만 되는 값
#
# - 셀 상태를 계산하는 과정
#     - forget gate layer (삭제 게이트)
#         - 정보를 제거하는 역할
#         1. 입력과 은닉 상태를 또 다른 가중치에 곱한 다음 시그모이드 함수를 통과(학습학습학습!!!!!)
#         2. 이전 타임스템의 셀 상태와 곱하여 새로운 셀 상태를 만듦
#             - 이 셀 상태가 오른쪽에서 tanh 함수를 통과하여 새로운 은닉 상태를 만드는 데 기여
#
#     - input gate layer(입력 게이트)
#
#         - 새로운 정보를 셀 상태에 추가
#           1. 입력과 은닉 상태를 각기 다른 가중치에 곱함
#           2. 하나는 시그모이드 함수(학습셀), 하나는 tanh 함수를 통과(학습셀)
#           3. 두 결과를 곱함
#           4. 이전 셀 상태와 더함

# %% [markdown]
# ## 데이터 준비

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 데이터 로드
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words = 500)

# %%
# 데이터 분할
x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train, 
    test_size = 0.2,
    stratify = y_train,
    random_state = 34
)

# %%
# 패딩 
train_seq = pad_sequences(x_train, maxlen = 100)
val_seq = pad_sequences(x_val, maxlen = 100)

# %%
# LSTM 모델 생성
model = keras.Sequential()
model.add(keras.Input(shape = (100,)))
model.add(keras.layers.Embedding(500, 128))
model.add(keras.layers.LSTM(8)) # 이것이 LSTM
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 100, 128)            │          64,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 8)                   │           4,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 68,393 (267.16 KB)
#  Trainable params: 68,393 (267.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - 파라미터 수가 simple rnn 과 다르다!
#     - (( 128 * 8 ) + ( 8 * 8 ) + 8)
#
# - LSTM 셀 파라미터 개수
#     -  (( 128 * 8 ) + ( 8 * 8 ) + 8) * 4
#
# - simple rnn 보다 4배 복잡

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate= 1e-4)
model.compile(
    optimizer= rmsprop, 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

cp_cb = keras.callbacks.ModelCheckpoint("./model/best-lstm-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# %%
history = model.fit(
    train_seq, y_train, epochs =100,
    batch_size =64, validation_data = (val_seq, y_val), callbacks = [es_cb, cp_cb]
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.5247 - loss: 0.6927 - val_accuracy: 0.5598 - val_loss: 0.6921
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5684 - loss: 0.6916 - val_accuracy: 0.5738 - val_loss: 0.6907
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5814 - loss: 0.6897 - val_accuracy: 0.5828 - val_loss: 0.6883
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5979 - loss: 0.6862 - val_accuracy: 0.5988 - val_loss: 0.6834
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6154 - loss: 0.6789 - val_accuracy: 0.6316 - val_loss: 0.6727
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6597 - loss: 0.6599 - val_accuracy: 0.6846 - val_loss: 0.6400
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7160 - loss: 0.6166 - val_accuracy: 0.7244 - val_loss: 0.5989
# Epoch 8/100
# ...

# %%
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 아름답다!
# - 드랍아웃을 적용해 볼까??

# %% [markdown]
# # 순환층에서의 드랍아웃은 좀 다르다~
#
# - 순환층은 자체적으로 드롭아웃 기능을 제공
#     - SimpleRNN 과 LSTM 클래스 모두 dropout 매개변수와 recurrent_dropout 매개변수를 가지고 있음
#         - dropout : 셀의 입력에 드롭아웃을 적용
#         - recurrent_dropout : 순환되는 은닉상태에 드롭아웃을 적용
#             - 버전에 따라 recurrent_dropout GPU 를 사용못하는 경우도 있음(버그~?: 학습속도가 줄어듦)

# %%
# LSTM 모델 생성
model2 = keras.Sequential()
model2.add(keras.Input(shape = (100,)))
model2.add(keras.layers.Embedding(500, 128))
model2.add(keras.layers.LSTM(8, dropout = 0.3)) # drop 적용~~~~~~
model2.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate= 1e-4)
model2.compile(
    optimizer= rmsprop, 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

cp_cb = keras.callbacks.ModelCheckpoint("./model/best-dropout-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# %%
history2 = model2.fit(
    train_seq, y_train, epochs =100,
    batch_size =64, validation_data = (val_seq, y_val), callbacks = [es_cb, cp_cb]
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5457 - loss: 0.6917 - val_accuracy: 0.5828 - val_loss: 0.6898
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5908 - loss: 0.6873 - val_accuracy: 0.6104 - val_loss: 0.6839
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6161 - loss: 0.6783 - val_accuracy: 0.6394 - val_loss: 0.6709
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.6530 - loss: 0.6574 - val_accuracy: 0.6724 - val_loss: 0.6385
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6997 - loss: 0.6016 - val_accuracy: 0.7352 - val_loss: 0.5511
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7379 - loss: 0.5435 - val_accuracy: 0.7592 - val_loss: 0.5188
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7589 - loss: 0.5159 - val_accuracy: 0.7716 - val_loss: 0.5011
# Epoch 8/100
# ...

# %%
plt.figure()

plt.plot(history2.history["loss"], label = "train_loss")
plt.plot(history2.history["val_loss"], label = "val_loss")

plt.plot(history2.history["accuracy"], label = "train_accuracy")
plt.plot(history2.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 아까보다 성능이 0.03 정도 좋아짐
# - 근데 딱히 차이가 없음

# %% [markdown]
# # 2개 층을 연결
#
# -  순환층을 연결할 때의 주의점
#     -  순환층의 은닉 상태는 샘플의 마지막 타임스텝에 대한 은닉 상태만 다음 층으로 전달
#         -  순환층을 쌓게 되면 모든 순환층에 순차 데이터가 필요함
#         -  앞쪽의 순환층이 모든 타임스텝에 대한 은닉 상태를 출력해야함
#             -  return_sequences 매개변수를 True 로 지정 (타임스텝의 수를 유지 (None, 타임스텝, 단어표현))

# %%
# LSTM 모델 생성
model3 = keras.Sequential()

# 입력층
model3.add(keras.Input(shape = (100,)))

# 전처리
model3.add(keras.layers.Embedding(500, 128))

# 한 겹 쌓아주기위해 return_sequences 를 True로 해서 shape를 유지함
model3.add(keras.layers.LSTM(8, dropout = 0.3, return_sequences=True))
# 마지막 친구는 아마 그냥 드가겠죠 
model3.add(keras.layers.LSTM(8, dropout = 0.3))

# 출력층
model3.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 100, 128)            │          64,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 8)              │           4,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 8)                   │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# ...

# %% [markdown]
# ![image.png](attachment:17f3236b-4f6f-4784-943c-f80f26e35e78.png)

# %% [markdown]
# - 첫 번째 LSTM
#     - 모든 타임스텝(100개)의 은닉 상태를 출력하기 때문에 출력의 크기가 (None, 100, 8)
#
# - 두 번째 LSTM
#     - 마지막 타임스텝의 은닉 상태만 출력하기 때문에 출력 크기가 (None, 8)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate= 1e-4)
model3.compile(
    optimizer= rmsprop, 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

cp_cb = keras.callbacks.ModelCheckpoint("./model/best-2rnn-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# %%
history3 = model3.fit(
    train_seq, 
    y_train, 
    epochs =100,
    batch_size =64, validation_data = (val_seq, y_val), callbacks = [es_cb, cp_cb]
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.5546 - loss: 0.6908 - val_accuracy: 0.6294 - val_loss: 0.6872
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.6294 - loss: 0.6756 - val_accuracy: 0.6694 - val_loss: 0.6505
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.6895 - loss: 0.6104 - val_accuracy: 0.7218 - val_loss: 0.5592
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.7366 - loss: 0.5490 - val_accuracy: 0.7610 - val_loss: 0.5146
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7623 - loss: 0.5155 - val_accuracy: 0.7600 - val_loss: 0.5045
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.7738 - loss: 0.4975 - val_accuracy: 0.7734 - val_loss: 0.4901
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7804 - loss: 0.4845 - val_accuracy: 0.7862 - val_loss: 0.4709
# Epoch 8/100
# ...

# %%
plt.figure()

plt.plot(history3.history["loss"], label = "train_loss")
plt.plot(history3.history["val_loss"], label = "val_loss")

plt.plot(history3.history["accuracy"], label = "train_accuracy")
plt.plot(history3.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 학습시간 존내 느리네.... => GRU 개발! ( 캐나다 한국인 아저씨가 만듦)

# %% [markdown]
# # GRU(Grated Reccurent Unit) 구조
#
# <img src ="image/rnn_lstm_gru.png">

# %% [markdown]
# - cell state 를 없애고 hidden state 에게 짬때렸다

# %% [markdown]
# - LSTM 을 간소화(cpu의 연산량을 줄임)한 버전
#
# - LSTM 처럼 셀 상태를 계산하지 않고 은닉 상태 하나만 포함
#
# - LSTM 보다 가중치가 적기 때문에 계산량이 적지만 성능은 LSTM 과 유사함
#     - 데이터 양이 적을 때는 GRU 의 성능이 더 좋고 데이터 양이 많을 때는 LSTM 의 성능이 더 좋아지는 경향이 있음
#
#     - GRU 와 LSTM 중 어떤 것이 더 낫다라고 말할 수는 없음

# %% [markdown]
# <img src = "./image/gru.png" width="500">

# %% [markdown]
# ![image.png](attachment:0cc9862e-72a8-42f0-a9c3-08fefe7d3dcc.png)

# %% [markdown]
# - GRU셀에는 은닉 상태와 입력에 가중치를 곱하고 절편을 더하는 작은 셀 3개가 들어 있음
#     - 2개는 시그모이드 활성화 함수를 사용하고 하나는 tanh 활성화 함수를 사용
#
# - reset_gate
#     - 셀의 출력이 은닉 상태에 바로 곱해져 삭제 게이트 역할을 수행
#
# - update gate
#     - 어떤 정보를 얼마만큼 유지하고 어떤 정보를 추가할지 결정하는 역할

# %%
model4 = keras.Sequential()
model4.add(keras.Input(shape=(100,)))
model4.add(keras.layers.Embedding(500, 128))
model4.add(keras.layers.GRU(8)) # GRU 적용
model4.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)              │ (None, 100, 128)            │          64,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 8)                   │           3,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67,321 (262.97 KB)
#  Trainable params: 67,321 (262.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - 입력값(128) * 유닛수(8) + 유닛수(8) * 유닛수(8) + 절편(유닛수(8)) * 3 = 3288
# - 인줄 알았지???? 24만큼 차이난다!
# - 업데이트가 있었습니다~~~~~ 절편같은거 추가했더니 더 좋아져서 파라미터가 추가된기다.
#
#
# - 입력값(128) * 유닛수(8) + 유닛수(8) * 유닛수(8) + 절편(유닛수(8)) + 절편(유닛수(8)) * 3 = 3,312 이 됨

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate= 1e-4)
model4.compile(
    optimizer= rmsprop, 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

cp_cb = keras.callbacks.ModelCheckpoint("./model/best-gru-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# %%
history4 = model4.fit(
    train_seq, 
    y_train, 
    epochs =100,
    batch_size =64, validation_data = (val_seq, y_val), callbacks = [es_cb, cp_cb]
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.5637 - loss: 0.6901 - val_accuracy: 0.5880 - val_loss: 0.6870
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5896 - loss: 0.6839 - val_accuracy: 0.6034 - val_loss: 0.6799
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6083 - loss: 0.6747 - val_accuracy: 0.6214 - val_loss: 0.6689
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6222 - loss: 0.6610 - val_accuracy: 0.6302 - val_loss: 0.6537
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6434 - loss: 0.6420 - val_accuracy: 0.6490 - val_loss: 0.6339
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6683 - loss: 0.6172 - val_accuracy: 0.6804 - val_loss: 0.6069
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7031 - loss: 0.5812 - val_accuracy: 0.7164 - val_loss: 0.5637
# Epoch 8/100
# ...

# %%
plt.figure()

plt.plot(history4.history["loss"], label = "train_loss")
plt.plot(history4.history["val_loss"], label = "val_loss")

plt.plot(history4.history["accuracy"], label = "train_accuracy")
plt.plot(history4.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 데이터가 작고 귀엽기 때문에 딱히 속도 차이는 모른다!

# %% [markdown]
# - 다 동일하게 dropout 등등 할수있음

# %% [markdown]
# # GRU 2개층 연결

# %%
model5 = keras.Sequential()
model5.add(keras.Input(shape=(100,)))
model5.add(keras.layers.Embedding(500, 128))
model5.add(keras.layers.GRU(8, dropout =0.3, return_sequences=True))
model5.add(keras.layers.GRU(8, dropout =0.3))
model5.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model5.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ (None, 100, 128)            │          64,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 100, 8)              │           3,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 8)                   │             432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# ...

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate= 1e-4)
model5.compile(
    optimizer= rmsprop, 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

cp_cb = keras.callbacks.ModelCheckpoint("./model/best-gru-dropout-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# %%
history5 = model5.fit(
    train_seq, 
    y_train, 
    epochs =100,
    batch_size =64, validation_data = (val_seq, y_val), callbacks = [es_cb, cp_cb]
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.5401 - loss: 0.6918 - val_accuracy: 0.5878 - val_loss: 0.6901
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.5789 - loss: 0.6881 - val_accuracy: 0.5954 - val_loss: 0.6845
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.6025 - loss: 0.6801 - val_accuracy: 0.6178 - val_loss: 0.6727
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.6273 - loss: 0.6630 - val_accuracy: 0.6414 - val_loss: 0.6507
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.6496 - loss: 0.6376 - val_accuracy: 0.6690 - val_loss: 0.6218
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.6706 - loss: 0.6085 - val_accuracy: 0.6860 - val_loss: 0.5939
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.6940 - loss: 0.5832 - val_accuracy: 0.6974 - val_loss: 0.5718
# Epoch 8/100
# ...

# %%
plt.figure()

plt.plot(history5.history["loss"], label = "train_loss")
plt.plot(history5.history["val_loss"], label = "val_loss")

plt.plot(history5.history["accuracy"], label = "train_accuracy")
plt.plot(history5.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # best model 검증

# %%
test_seq = pad_sequences( x_test, maxlen = 100 )

# %%
rnn_model = keras.models.load_model("./model/best-gru-dropout-model.keras")
rnn_model.evaluate(test_seq, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8023 - loss: 0.4288
# [0.42884641885757446, 0.8023200035095215]
