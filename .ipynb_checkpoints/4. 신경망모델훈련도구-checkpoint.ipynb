# %% [markdown]
# - 머신러닝 알고리즘은 모델의 구조가 어느 정도 고정되어 있음
#     - 좋은 성능을 내기 위해서는 매개변수를 조정하고 훈련하는 과정을 반복
#
# - 딥러닝은 구조를 직접 설계해야함
#     - 좋은 성능을 내기 위해 다룰 수 있는 다양한 개념과 도구들을 이해할 필요가 있음

# %% [markdown]
# # 손실 곡선
#
# - 케라스의 fit() 메서드는 History 클래스의 객체를 반환
# - History 객체 : 훈련 과정에서 **계산한 지표(손실과 정확도값)가 저장되어 있음**
# - 이 값을 사용하여 그래프를 그려서 훈련 성과를 확인

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
scaled_train = x_train / 255 # 성능향상을 위한 스케일링~~~~
scaled_train, scaled_val, y_train, y_val = train_test_split(
    scaled_train,
    y_train, 
    test_size =0.2, 
    stratify = y_train, 
    random_state = 34
)

# %%
# 모델 정의 함수
def model_fn(a_layer = None):
    model = keras.Sequential()
    model.add(keras.Input(shape = (28,28)))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(100, activation ="relu"))

    # 추가하고 싶은 층
    if a_layer:
        model.add(a_layer)

    model.add(keras.layers.Dense(10, activation = "softmax"))

    return model

# %%
model = model_fn()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 일단 여기까지는 똑같습니다...

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model.fit(scaled_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8096 - loss: 0.5369
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8574 - loss: 0.3958
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8714 - loss: 0.3570
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8797 - loss: 0.3338
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8852 - loss: 0.3190

# %%
# history 확인
print(history.history)
print(history.history.keys())
# Out:
# {'accuracy': [0.8096250295639038, 0.8573541641235352, 0.8713541626930237, 0.8797083497047424, 0.8852291703224182], 'loss': [0.5369265675544739, 0.3958077132701874, 0.3570058047771454, 0.33375534415245056, 0.3190254867076874]}
# dict_keys(['accuracy', 'loss'])

# %% [markdown]
# ### 이 정보를 가지고 시각화

# %%
plt.figure()

plt.plot(history.history["loss"])
plt.xlabel("epoch")
plt.ylabel("loss")

plt.show()

# %%
plt.figure()

plt.plot(history.history["accuracy"], "r")
plt.xlabel("epoch")
plt.ylabel("accuracy")

plt.show()

# %%
# epoch 를 20으로 늘려보자
model = model_fn()
model.compile(
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)
history = model.fit(scaled_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8125 - loss: 0.5303
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8594 - loss: 0.3928
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8715 - loss: 0.3541
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8810 - loss: 0.3313
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8857 - loss: 0.3168
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8916 - loss: 0.3060
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8943 - loss: 0.2940
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8983 - loss: 0.2850
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9005 - loss: 0.2785
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9031 - loss: 0.2732
# Epoch 11/20
# ...

# %%
# 두개 한번에 그려보자 (단위가 비슷하니까)
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 검증 손실
#
# - 에포크에 따른 과대적합과 과소적합을 파악하려면 검증 세트에 대한 점수도 확인해야함
#
# - **케라스에서는 fit() 메서드에 검증데이터를 전달할 수 있음**

# %%
model = model_fn()
model.compile(loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

history = model.fit(
    scaled_train, 
    y_train, 
    epochs = 20,
    validation_data  =(scaled_val, y_val), # 검증값만 만들어냄
    batch_size=32
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8125 - loss: 0.5335 - val_accuracy: 0.8469 - val_loss: 0.4198
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8589 - loss: 0.3918 - val_accuracy: 0.8683 - val_loss: 0.3687
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8717 - loss: 0.3569 - val_accuracy: 0.8820 - val_loss: 0.3501
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8797 - loss: 0.3338 - val_accuracy: 0.8678 - val_loss: 0.3786
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8835 - loss: 0.3220 - val_accuracy: 0.8806 - val_loss: 0.3541
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8892 - loss: 0.3097 - val_accuracy: 0.8847 - val_loss: 0.3469
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8934 - loss: 0.2983 - val_accuracy: 0.8772 - val_loss: 0.3735
# Epoch 8/20
# ...

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# 에포크 20으로 늘리고 validation_data 넣어줌
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 완벽하게 과대적합 모델이 되었다
#
# - 훈련 손식은 곗고 감소하는데 검증 손실은 감소하다가 상승하여 과대적합 모델이 만들어짐
#     - **검증 손실이 상승하는 시점을 가능한한 뒤로 늦출필요가 있음**
# - ![image.png](attachment:4ab132b5-fd1e-47a9-a337-6c71dfd58212.png)

# %% [markdown]
# - 검증 성능을 높히기 위해 옵티마이저를 만져!

# %%
# Adam 옵티마이저 선택
model = model_fn()
model.compile(optimizer= "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs =20, validation_data = (scaled_val, y_val), batch_size =32)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8157 - loss: 0.5302 - val_accuracy: 0.8533 - val_loss: 0.4234
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8549 - loss: 0.3987 - val_accuracy: 0.8597 - val_loss: 0.3917
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8716 - loss: 0.3544 - val_accuracy: 0.8640 - val_loss: 0.3792
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8796 - loss: 0.3296 - val_accuracy: 0.8783 - val_loss: 0.3400
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8857 - loss: 0.3086 - val_accuracy: 0.8807 - val_loss: 0.3380
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8929 - loss: 0.2915 - val_accuracy: 0.8832 - val_loss: 0.3357
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8978 - loss: 0.2779 - val_accuracy: 0.8829 - val_loss: 0.3267
# Epoch 8/20
# ...

# %%
# 옵티마이저 변경
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# ![image.png](attachment:354845f0-9350-43aa-8561-64c412573ca6.png)

# %% [markdown]
# - 옵티마이저설정이 과대적합을 방지하는게 아님

# %% [markdown]
# - RMSProp을 사용할 때 보다 검증 손실 그래프의 감소 추세가 길게 이어지고 있어 Adam 옵티마이저가 이 데이터 셋에 잘 맞는 것으로 보임

# %% [markdown]
# # 드롭 아웃
# <img src="./image/dropout.png" width=500>

# %% [markdown]
# - 훈련 과정에서 층의 일부 유닛을 랜덤하게 끄는 것으로(출력을 0으로 만드는 것으로) 과대적합을 방지
#     - 특정 유닛에 과대하게 **의존하는 것**을 줄일 수 있음
#
#     - 일부 유닛의 출력이 없을 수 있다는 점을 감안하여 학습하게 됨
#         - 모든 입력갑셍 대한 충분한 주의를 기울이는 방향으로 학습
#
# - 드롭아웃은 케라스에서 Dropout 클래스로 제공
#
# - 특정 층 뒤에 드롭아웃을 두어 해당 츠의 출력을 랜덤하게 0으로 만듦
#
# - Flatten과 마찬가지로 층처럼 사용되지만 훈련되는 모델 파라미터가 없음

# %%
model = model_fn(keras.layers.Dropout(0.3)) # 0.3 
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_6 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 10)                  │           1,010 │
# ...

# %% [markdown]
# - 드롭아웃 층은 입력과 출력의 크기가 같음
#     - 일부 유닛의 출력을 0으로 만들지만 전체 출력 배열의 크기를 바꾸지 않음
#
# - 모델 훈련이 끝난 후에 평가나 예측을 수행할 때에는 드롭아웃을 적용하지 않아야 함
#
#     - 훈련된 모든 유닛을 사용해야 올바른 예측 수행 가능
#
#     - 케라스에서는 모델을 평가와 예측 할때는 **자동으로 드롭아웃 적용안함**

# %%
# Dropout 적용 ( 배열의 형태는 같다 그냥 값만 0 으로 바뀌는 거임 )
model.compile(optimizer= "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs =20, validation_data = (scaled_val, y_val), batch_size =32)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7932 - loss: 0.5891 - val_accuracy: 0.8506 - val_loss: 0.4183
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8422 - loss: 0.4386 - val_accuracy: 0.8604 - val_loss: 0.3896
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8532 - loss: 0.4028 - val_accuracy: 0.8648 - val_loss: 0.3672
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8612 - loss: 0.3812 - val_accuracy: 0.8643 - val_loss: 0.3644
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8674 - loss: 0.3637 - val_accuracy: 0.8750 - val_loss: 0.3457
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8700 - loss: 0.3524 - val_accuracy: 0.8753 - val_loss: 0.3468
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8736 - loss: 0.3405 - val_accuracy: 0.8776 - val_loss: 0.3335
# Epoch 8/20
# ...

# %%
# Dropout 적용
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# ![image.png](attachment:cfe6a627-5c97-4f7f-b489-311266285751.png)

# %% [markdown]
# - 앞선 방법들에 비해 loss 와 acc 가 비교적 일정하게 유지!!!!

# %% [markdown]
# # 모델 저장과 복원
#
# - 케라스 모델은 모델의 파라미터를 저장하는 save_weights() 메서드를 제공
#
# - 모델 구조와 모델 파라미터를 제공하는 save() 메서드 제공

# %%
model.save_weights("./model/model.weights.h5")
model.save("./model/model-whole.keras")

# %% [markdown]
# ## 모델 파라미터만 읽어오기

# %%
weight_model = model_fn(keras.layers.Dropout(0.3)) # 구조도 똑같아야함
weight_model.load_weights("./model/model.weights.h5")

# %%
weight_model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_8 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 10)                  │           1,010 │
# ...

# %% [markdown]
# - load_weights() 메서드를 사용하면 save_weights() 로 저장했던 모델과 정확히 같은 구조를 가져야함
#
# - evaluate() 를 사용하기 전에 compile() 을 반드시 실행

# %%
weight_model.predict(scaled_val)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# array([[1.29125779e-02, 3.15263693e-04, 1.41417971e-02, ...,
#         6.04059233e-06, 7.63166070e-01, 7.27618271e-07],
#        [1.31991896e-04, 3.63945496e-09, 2.41866466e-02, ...,
#         1.55117455e-13, 1.37934680e-04, 5.22220722e-12],
#        [7.56495725e-03, 7.60130002e-04, 1.57871470e-01, ...,
#         5.79428807e-08, 1.04355847e-03, 2.88358069e-06],
#        ...,
#        [1.08083725e-04, 1.28489501e-06, 6.67689800e-01, ...,
#         6.19170751e-15, 3.26279910e-08, 3.39100085e-16],
#        [9.99562681e-01, 2.92151303e-10, 5.38350787e-06, ...,
#         2.35083489e-18, 1.14488707e-07, 9.94822462e-17],
#        [4.23232879e-04, 8.96760284e-08, 9.92634118e-01, ...,
#         4.90116170e-10, 1.57844990e-08, 2.30985320e-09]],
#       shape=(12000, 10), dtype=float32)

# %%
# argmax 로 어떤것이 제일 높은 확률값을 가졌는가를 아는게 중요
np.argmax(weight_model.predict(scaled_val), axis =-1) # shape=(12000, 10) 맨 뒤의 차원 짜부~
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# array([8, 4, 4, ..., 2, 0, 2], shape=(12000,))

# %%
# val_labels 로 저장
val_labels = np.argmax(weight_model.predict(scaled_val), axis =-1) # shape=(12000, 10) 맨 뒤의 차원 짜부~
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step

# %%
print("예측값", val_labels)
print("정답값", y_val)
# Out:
# 예측값 [8 4 4 ... 2 0 2]
# 정답값 [2 6 2 ... 2 0 2]

# %%
val_labels == y_val
# Out:
# array([False, False, False, ...,  True,  True,  True], shape=(12000,))

# %% [markdown]
# ##  정확도 계산

# %%
# 정확도 계산
np.mean(val_labels == y_val)
# Out:
# np.float64(0.88875)

# %% [markdown]
# - 케라스의 predict() 메서드는 모델의 예측을 수행
#     - 종속변수가 10개의 클래스로 이루어져 있기 때문에 각 클래스에 대한 확률을 반환
# - predict() 결과에서 가장 큰 값을 고르기 위해 argmax() 함수를 사용
#     - 배열에서 가장 큰 값의 인덱스를 반환
#     - 몇 번째 클래스에 대한 확률값이 가장 큰 지 반환
#         - 몇 번째 클래스로 예측했는지 알 수 있음
#
# - argmax() 함수의 axis = -1 은 배열의 마지막 차원을 따라서 최댓값을 고름
#     - axis = 1 이면 열을 따라 각 행의 최댓값의 인덱스를 선택
#     - axis = 0 이면 행을 따라 각 열의 최댓값의 인덱스를 선택
# - argmax() 로 고른 인덱스와 타깃 인덱스를 비교하여 같으면 1, 다르면
#     - 위의 평균을 구하면 정확도가 됨

# %% [markdown]
# # 모델 전체 읽어오기

# %%
whole_model = keras.models.load_model("./model/model-whole.keras")

# %%
whole_model.evaluate(scaled_val,y_val)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 923us/step - accuracy: 0.8888 - loss: 0.3289
# [0.32893022894859314, 0.8887500166893005]

# %% [markdown]
# # 콜백(callback)
#
# - 훈련 과정 중간에 어떤 작업을 수행할 수 있게 하는 객체
#
# - fit() 메서드의 callbacks 매개변수에 리스트로 전달하여 사용

# %% [markdown]
# ## ModelCheckpoint 콜백
#
# - 최상의 검증점수! 모델 저장

# %%
cp_cb = keras.callbacks.ModelCheckpoint("./model/best-model.keras", save_best_only = True)
# save_best_only : 가장 상태가 좋을때 val_loss 가 낮은것이 있을때 저장

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer= "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
model.fit(
    scaled_train, 
    y_train, 
    epochs = 20, 
    validation_data=(scaled_val, y_val), 
    callbacks=[cp_cb], batch_size=32
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7952 - loss: 0.5927 - val_accuracy: 0.8494 - val_loss: 0.4241
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8419 - loss: 0.4392 - val_accuracy: 0.8642 - val_loss: 0.3803
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8527 - loss: 0.4054 - val_accuracy: 0.8641 - val_loss: 0.3712
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8604 - loss: 0.3833 - val_accuracy: 0.8693 - val_loss: 0.3581
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8665 - loss: 0.3664 - val_accuracy: 0.8766 - val_loss: 0.3448
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8703 - loss: 0.3551 - val_accuracy: 0.8782 - val_loss: 0.3383
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8732 - loss: 0.3465 - val_accuracy: 0.8735 - val_loss: 0.3448
# Epoch 8/20
# ...

# %% [markdown]
# - 훈련한 후에 best-model.keras 에 최상의 val_loss 를 낸 모델이 저장됨

# %%
model.evaluate(scaled_val, y_val)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.8839 - loss: 0.3273
# [0.3272523880004883, 0.8839166760444641]

# %%
best_model = keras.models.load_model("./model/best-model.keras")
best_model.evaluate(scaled_val, y_val)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8880 - loss: 0.3184
# [0.3183589577674866, 0.8880000114440918]

# %% [markdown]
# - ModelCheckpoint 콜백이 가장 낮은 검증 손실값의 모델을 자동으로 저장해주어 편하지만 여전히 20번 훈련해야함

# %% [markdown]
# ## EarlyStopping 콜백
#
# - 과대적합이 시작되기 전에(검증 점수가 상승할 때) 훈련을 미리 중지하는 것을 조기종료라고함
#
# - 훈련 에포크 회수를 제한하는 역할,  모델 과대적합 막아줌

# %%
cp_cb = keras.callbacks.ModelCheckpoint("./model/best-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(
    patience= 2, # 인내심, 몇 에포크를 지켜볼것인가
    restore_best_weights=True 
)

# %% [markdown]
# - patience
#     - 검증 점수가 향상되지 않더라도 지켜볼 에포크 수
#     - patience 가 2라면 2번연속 검증 점수가 향상되지 않으면 훈련 중지
#
# - restore_best_weights
#     - 가장 낮은 검증 손실을 낸 모델의 상태로 되돌림

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)
history = model.fit(
    scaled_train,
    y_train,
    epochs =20,
    validation_data = (scaled_val, y_val),
    callbacks =[es_cb, cp_cb],
    batch_size=32
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7908 - loss: 0.5886 - val_accuracy: 0.8363 - val_loss: 0.4394
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8409 - loss: 0.4385 - val_accuracy: 0.8593 - val_loss: 0.3904
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8543 - loss: 0.4013 - val_accuracy: 0.8655 - val_loss: 0.3694
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8590 - loss: 0.3831 - val_accuracy: 0.8744 - val_loss: 0.3460
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8651 - loss: 0.3638 - val_accuracy: 0.8695 - val_loss: 0.3593
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8683 - loss: 0.3537 - val_accuracy: 0.8698 - val_loss: 0.3440
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8743 - loss: 0.3425 - val_accuracy: 0.8817 - val_loss: 0.3349
# Epoch 8/20
# ...

# %%
# Dropout 적용
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# ### 몇 번째 에포크에서 중지 되었는지 확인

# %%
print(es_cb.stopped_epoch)
# Out:
# 11

# %% [markdown]
# - 12번째 에포크까지 훈련한 후 중지
# - 10번째가 최상

# %% [markdown]
# # validation_split
#
# - 훈련 데이터를 자체적으로 훈련/검증 셋으로 나누어서 훈련, 검증을 수행

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
scaled_train = x_train / 255
scaled_test = x_test / 255

# %%
cp_cb = keras.callbacks.ModelCheckpoint("./model/best-model.keras", save_best_only = True)
es_cb = keras.callbacks.EarlyStopping(
    patience= 2, # 인내심, 몇 에포크를 지켜볼것인가
    restore_best_weights=True 
)

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)
history = model.fit(
    scaled_train,
    y_train,
    epochs =20,
    validation_split= 0.2, # 새로나왔어요!
    # validation_data = (scaled_val, y_val),
    callbacks =[es_cb, cp_cb],
    batch_size=32
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7929 - loss: 0.5919 - val_accuracy: 0.8493 - val_loss: 0.4183
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8420 - loss: 0.4416 - val_accuracy: 0.8597 - val_loss: 0.3853
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8524 - loss: 0.4059 - val_accuracy: 0.8633 - val_loss: 0.3709
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8619 - loss: 0.3820 - val_accuracy: 0.8706 - val_loss: 0.3624
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8672 - loss: 0.3663 - val_accuracy: 0.8743 - val_loss: 0.3433
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8680 - loss: 0.3560 - val_accuracy: 0.8673 - val_loss: 0.3564
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8741 - loss: 0.3433 - val_accuracy: 0.8702 - val_loss: 0.3514

# %%
# Dropout 적용
plt.figure()

plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["val_loss"], label = "val_loss")

plt.plot(history.history["accuracy"], label = "train_accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")

plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %%
model.evaluate(scaled_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.8687 - loss: 0.3717
# [0.37172767519950867, 0.8687000274658203]
